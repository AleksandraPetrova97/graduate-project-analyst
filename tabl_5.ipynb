# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame({'2020': [1987100, 928900, 151200, 1763000, 1816800, 15900, 3087900, 58700, 826400],
                   '2021': [2101100, 1192800, 175200, 1388300, 1531600, 1300, 2847700, 4600, 808200],
                   '2022': [1869100, 1269500, 183900, 1103800, 1059300, 300, 2142100, 0, 1020000]}, index=['массовое катание', 'прокат коньков',
                    'заточка коньков', 'Тренажерный зал', 'Фитнес', 'Солярий',  'хоккей (продажа  билетов)',
                    'фигурное катание  (продажа билетов) ', 'реклама'])
df
# Out:
#                                          2020     2021     2022
# массовое катание                      1987100  2101100  1869100
# прокат коньков                         928900  1192800  1269500
# заточка коньков                        151200   175200   183900
# Тренажерный зал                       1763000  1388300  1103800
# Фитнес                                1816800  1531600  1059300
# Солярий                                 15900     1300      300
# хоккей (продажа  билетов)             3087900  2847700  2142100
# фигурное катание  (продажа билетов)     58700     4600        0
# реклама                                826400   808200  1020000

# %%
df['Абсолютное изменение 2021г. к 2020г.'] = pd.Series(df['2021'] - df['2020'])
df['Абсолютное изменение 2022г. к 2021г.'] = pd.Series(df['2022'] - df['2021'])
df['Абсолютное изменение 2022г. к 2020г.'] = pd.Series(df['2022'] - df['2020'])
df
# Out:
#                                          2020     2021     2022  \
# массовое катание                      1987100  2101100  1869100
# прокат коньков                         928900  1192800  1269500
# заточка коньков                        151200   175200   183900
# Тренажерный зал                       1763000  1388300  1103800
# Фитнес                                1816800  1531600  1059300
# Солярий                                 15900     1300      300
# хоккей (продажа  билетов)             3087900  2847700  2142100
# фигурное катание  (продажа билетов)     58700     4600        0
# реклама                                826400   808200  1020000
#
#                                       Абсолютное изменение 2021г. к 2020г.  \
# массовое катание                                                    114000
# прокат коньков                                                      263900
# заточка коньков                                                      24000
# Тренажерный зал                                                    -374700
# Фитнес                                                             -285200
# Солярий                                                             -14600
# хоккей (продажа  билетов)                                          -240200
# фигурное катание  (продажа билетов)                                 -54100
# реклама                                                             -18200
#
#                                       Абсолютное изменение 2022г. к 2021г.  \
# массовое катание                                                   -232000
# прокат коньков                                                       76700
# заточка коньков                                                       8700
# Тренажерный зал                                                    -284500
# Фитнес                                                             -472300
# Солярий                                                              -1000
# хоккей (продажа  билетов)                                          -705600
# фигурное катание  (продажа билетов)                                  -4600
# реклама                                                             211800
#
#                                       Абсолютное изменение 2022г. к 2020г.
# массовое катание                                                   -118000
# прокат коньков                                                      340600
# заточка коньков                                                      32700
# Тренажерный зал                                                    -659200
# Фитнес                                                             -757500
# Солярий                                                             -15600
# хоккей (продажа  билетов)                                          -945800
# фигурное катание  (продажа билетов)                                 -58700
# реклама                                                             193600

# %%
df['Темп роста, 2021 г. к 2020 г. %'] = np.round((df['2021'] / df['2020']) * 100, 1)
df['Темп роста, 2022 г. к 2021 г. %'] = np.round((df['2022'] / df['2021']) * 100, 1)
df['Темп роста, 2022 г. к 2020 г. %'] = np.round((df['2022'] / df['2020']) * 100, 1)
df
# Out:
#                                          2020     2021     2022  \
# массовое катание                      1987100  2101100  1869100
# прокат коньков                         928900  1192800  1269500
# заточка коньков                        151200   175200   183900
# Тренажерный зал                       1763000  1388300  1103800
# Фитнес                                1816800  1531600  1059300
# Солярий                                 15900     1300      300
# хоккей (продажа  билетов)             3087900  2847700  2142100
# фигурное катание  (продажа билетов)     58700     4600        0
# реклама                                826400   808200  1020000
#
#                                       Абсолютное изменение 2021г. к 2020г.  \
# массовое катание                                                    114000
# прокат коньков                                                      263900
# заточка коньков                                                      24000
# Тренажерный зал                                                    -374700
# Фитнес                                                             -285200
# Солярий                                                             -14600
# хоккей (продажа  билетов)                                          -240200
# фигурное катание  (продажа билетов)                                 -54100
# реклама                                                             -18200
#
#                                       Абсолютное изменение 2022г. к 2021г.  \
# массовое катание                                                   -232000
# прокат коньков                                                       76700
# заточка коньков                                                       8700
# Тренажерный зал                                                    -284500
# Фитнес                                                             -472300
# Солярий                                                              -1000
# хоккей (продажа  билетов)                                          -705600
# фигурное катание  (продажа билетов)                                  -4600
# реклама                                                             211800
#
#                                       Абсолютное изменение 2022г. к 2020г.  \
# массовое катание                                                   -118000
# прокат коньков                                                      340600
# заточка коньков                                                      32700
# Тренажерный зал                                                    -659200
# Фитнес                                                             -757500
# Солярий                                                             -15600
# хоккей (продажа  билетов)                                          -945800
# фигурное катание  (продажа билетов)                                 -58700
# реклама                                                             193600
#
#                                       Темп роста, 2021 г. к 2020 г. %  \
# массовое катание                                                105.7
# прокат коньков                                                  128.4
# заточка коньков                                                 115.9
# Тренажерный зал                                                  78.7
# Фитнес                                                           84.3
# Солярий                                                           8.2
# хоккей (продажа  билетов)                                        92.2
# фигурное катание  (продажа билетов)                               7.8
# реклама                                                          97.8
#
#                                       Темп роста, 2022 г. к 2021 г. %  \
# массовое катание                                                 89.0
# прокат коньков                                                  106.4
# заточка коньков                                                 105.0
# Тренажерный зал                                                  79.5
# Фитнес                                                           69.2
# Солярий                                                          23.1
# хоккей (продажа  билетов)                                        75.2
# фигурное катание  (продажа билетов)                               0.0
# реклама                                                         126.2
#
#                                       Темп роста, 2022 г. к 2020 г. %
# массовое катание                                                 94.1
# прокат коньков                                                  136.7
# заточка коньков                                                 121.6
# Тренажерный зал                                                  62.6
# Фитнес                                                           58.3
# Солярий                                                           1.9
# хоккей (продажа  билетов)                                        69.4
# фигурное катание  (продажа билетов)                               0.0
# реклама                                                         123.4
