# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("год_новый.csv", sep=';', encoding='windows-1251')
data
# Out:
#            наименование услуги  годовая прибыль   год
# 0                      солярий              1.0  2020
# 1                       фитнес            646.1  2020
# 2              тренажерный зал            640.2  2020
# 3                      солярий              2.0  2021
# 4                       фитнес            961.2  2021
# 5              тренажерный зал            950.2  2021
# 6                      солярий              1.0  2022
# 7                       фитнес            855.4  2022
# 8              тренажерный зал            807.6  2022
# 9             массовое катание           1102.7  2020
# 10              прокат коньков            731.2  2020
# 11             заточка коньков            128.5  2020
# 12            массовое катание           1643.0  2021
# 13              прокат коньков           1081.6  2021
# 14             заточка коньков            185.2  2021
# 15            массовое катание           1429.4  2022
# ...

# %%
data['годовая прибыль']=data['годовая прибыль'].astype('float64')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   наименование услуги  24 non-null     object
#  1   годовая прибыль      24 non-null     float64
#  2   год                  24 non-null     int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 708.0+ bytes

# %%
df['Абсолютное изменение 2021г. к 2020г.'] = pd.Series(df['2021'] - df['2020'])
df['Абсолютное изменение 2022г. к 2021г.'] = pd.Series(df['2022'] - df['2021'])
df['Абсолютное изменение 2022г. к 2020г.'] = pd.Series(df['2022'] - df['2020'])
df

# %%
df['Темп роста, 2021 г. к 2020 г. %'] = np.round((df['2021'] / df['2020']) * 100, 1)
df['Темп роста, 2022 г. к 2021 г. %'] = np.round((df['2022'] / df['2021']) * 100, 1)
df['Темп роста, 2022 г. к 2020 г. %'] = np.round((df['2022'] / df['2020']) * 100, 1)
df

# %%
# задаем цвета диаграммы
colors = ['violet', 'aqua', 'gold']
# создаем фигуру и задаем её размер
plt.figure(figsize=(10,4))
# задаем данные диаграммы
splot= sns.barplot(x='наименование услуги', y='годовая прибыль',
            ci=None, hue= "год", width=0.8, data = data, palette=colors)
# # добавляем метки данных
plt.bar_label(splot.containers[0],size=6)
plt.bar_label(splot.containers[1],size=6)
plt.bar_label(splot.containers[2],size=6)
#  подписываем x и y
plt.xlabel('Наименование услуги')
plt.ylabel('Средняя стоимость услуг, тыс.руб')
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Администратор\AppData\Local\Temp\ipykernel_5292\107047418.py:6: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   splot= sns.barplot(x='наименование услуги', y='годовая прибыль',
