# %% [markdown]
# Создадим в ручную дата фрейм

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("Динамика роста цен.csv", sep=';', encoding='windows-1251')
data
# Out:
#                          Наименование услуги  Год предоставления услуги  \
# 0     Билет на массовое катание для взрослых                       2020
# 1         Льготный билет на массовое катание                       2020
# 2                             Прокат коньков                       2020
# 3   Абонемент на 1 месяц без проката коньков                       2020
# 4    Абонемент на 1 месяц с прокатом коньков                       2020
# 5                            Заточка коньков                       2020
# 6        Разогрев 1 пары ботинок в термопечи                       2020
# 7     Билет на массовое катание для взрослых                       2023
# 8         Льготный билет на массовое катание                       2023
# 9                             Прокат коньков                       2023
# 10  Абонемент на 1 месяц без проката коньков                       2023
# 11   Абонемент на 1 месяц с прокатом коньков                       2023
# 12                           Заточка коньков                       2023
# 13       Разогрев 1 пары ботинок в термопечи                       2023
#
#     Стоимость услуги
# 0                100
# 1                 50
# 2                 80
# 3               1000
# 4               1900
# 5                120
# 6                250
# 7                150
# 8                 75
# 9                150
# 10              1800
# 11              3000
# 12               200
# 13               300

# %%
# задаем цвета диаграммы
colors = ['violet', 'aqua']
# создаем фигуру и задаем её размер
plt.figure(figsize=(10,4))
# задаем данные диаграммы
splot= sns.barplot(x='Стоимость услуги', y='Наименование услуги',
            ci=None, hue= "Год предоставления услуги", data = data, palette=colors)
# добавляем метки данных
plt.bar_label(splot.containers[0],size=10, label_type='center')
plt.bar_label(splot.containers[1],size=10, label_type='center')
#  подписываем x и y
plt.xlabel('Наименование услуги')
plt.ylabel('Средняя стоимость услуг, руб')

plt.show()
# Out:
# C:\Users\Администратор\AppData\Local\Temp\ipykernel_3776\4059509809.py:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   splot= sns.barplot(x='Стоимость услуги', y='Наименование услуги',
# Text(0, 0.5, 'Средняя стоимость услуг, руб')

# %%
df['Темп роста, %'] = np.round((df['2023'] / df['2020']) * 100, 2)
df
# Out:
#                                                     2020  2023  Темп роста, %
# Билет на массовое катание для взрослых               100   150         150.00
# Льготный билет на массовое катание                    50    75         150.00
# Прокат коньков                                        80   150         187.50
# Абонемент на 1 месяц без проката коньков            1000  1800         180.00
# Абонемент на 1 месяц с прокатом коньков             1900  3000         157.89
# Заточка коньков                                      120   200         166.67
# Разогрев 1 пары фигурных и хоккейных ботинок в ...   250   300         120.00
