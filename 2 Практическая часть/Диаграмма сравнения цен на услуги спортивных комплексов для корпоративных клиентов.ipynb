# %% [markdown]
# > Для начала импортируем необходимые библиотеки для анализы и визуализации имеющихся данных.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_corporate_services = pd.read_csv("Приложение_1_Цены на услуги спортивных комплексов для корпоративных клиентов.csv", sep=';', encoding='windows-1251')

# %%
df_corporate_services.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Спортивный комплекс     10 non-null     object
#  1   Предоставляемая услуга  10 non-null     object
#  2   Стоимость услуги        10 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 372.0+ bytes

# %%
df_corporate_services.groupby('Предоставляемая услуга').count()
# Out:
#                                       Спортивный комплекс  Стоимость услуги
# Предоставляемая услуга
# Аренда ледовой арены                                    5                 5
# Техническое  обеспечение мероприятий                    5                 5

# %%
data = pd.crosstab(index=df['наименование услуги'],
                    columns=df['год'])
                    
data

# %%
splot = sns.barplot(x='Стоимость услуги',y='Предоставляемая услуга',data=df_corporate_services, 
                    hue= "Спортивный комплекс", palette="Set1")

for i in splot.containers:
    splot.bar_label(i,label_type='center')    
     
plt.xlabel('Стоимость услуги, руб')
plt.ylabel('Наименование услуги')
plt.xticks (size=10)
plt.yticks (size=10)
# Out:
# (array([0, 1]),
#  [Text(0, 0, 'Аренда ледовой арены'),
#   Text(0, 1, 'Техническое  обеспечение мероприятий')])
